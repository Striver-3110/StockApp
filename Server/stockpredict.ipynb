# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

data_path = "C:\\Users\\Admin\\OneDrive\\Documents\\Python\\database"

delimiter = ","


# Sample prediction function (replace with your actual logic)
def predict_stock_price(symbol, historical_data):
    # Simulate prediction based on historical data (replace with your model)
    predicted_price = historical_data.iloc[-1]* 1.1  # Simple increase of 10%
    return predicted_price


# Load historical data (replace with your data source)
data = pd.read_csv(data_path + "\\Data\\Stocks\\aa.us.txt", delimiter=delimiter, index_col="Date", parse_dates=True)
# print(data["Close"])
# # Get user input (simulated)
symbol = "Close"

# # Make prediction
predicted_price = predict_stock_price(symbol, data[symbol])

# # Create visualization (replace with your desired chart)
plt.figure(figsize=(8, 6))

# plt.plot(data[symbol][-1],predicted_price)
plt.plot(data["Close"], label="Historical Price")
plt.axhline(y=predicted_price, color="red", linestyle="--", label="Predicted Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.title(f"Stock Price Prediction for {symbol}")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

# # Save visualization as image (replace with interactive element if needed)
plt.savefig("prediction_plot.png")
